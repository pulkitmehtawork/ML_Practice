# %% [markdown]
# # In this tutorial , we will sort data using pandas. We will use AV's big mart sales prediction data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("bigmart_data.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# sort by out let establishment year


df.sort_values(by = "Outlet_Establishment_Year",ascending=False)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5371           FDC11       20.500          Low Fat         0.142370
# 6389           FDR07       21.350          Low Fat         0.078061
# 2064           FDG50        7.405          Low Fat         0.015334
# 3839           DRI37       15.850          Low Fat         0.108036
# 6392           FDO52       11.600          Regular         0.077479
# 7643           FDZ31       15.350          Regular         0.113678
# 6390           FDF41       12.150          Low Fat         0.131714
# 845            FDT21        7.420          Low Fat         0.020475
# 843            NCR17        9.800          Low Fat         0.024483
# 7655           FDX28        6.325          Low Fat         0.125688
# 3843           FDU34       18.250          Low Fat         0.075501
# 3844           FDP31       21.100          Regular         0.162163
# 6386           FDA13       15.850          Low Fat         0.078875
# ...

# %%
df.sort_values(by = ["Outlet_Establishment_Year","Item_Outlet_Sales"],ascending=False,inplace = True)

# %%
df.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 43             FDC02        21.35          Low Fat         0.069103
# 2803           FDU51        20.20          Regular         0.096907
# 641            FDY51        12.50          Low Fat         0.081465
# 2282           NCX30        16.70          Low Fat         0.026729
# 2887           FDR25        17.00          Regular         0.140090
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 43       Canned  259.9278            OUT018                       2009
# 2803       Meat  175.5028            OUT018                       2009
# 641        Meat  220.7798            OUT018                       2009
# 2282  Household  248.4776            OUT018                       2009
# 2887     Canned  265.1884            OUT018                       2009
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...
